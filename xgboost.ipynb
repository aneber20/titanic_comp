# %% [markdown]
# Training and testing XGBoost

# %%
import xgboost as xgb

# %%
## Load in data
dtrain = xgb.DMatrix('C:/Users/Aneber/VScode Projects/titanic_competition/data/processed/train_processed.csv?format=csv&label_column=14')
dval = xgb.DMatrix('C:/Users/Aneber/VScode Projects/titanic_competition/data/processed/valid_processed.csv?format=csv&label_column=14')

# %%
## Set parameters
param = {'max_depth': 3, 'objective':'binary:hinge', 'nthread':2}
evallist = [(dtrain, 'train'), (dval, 'test')]

# %%
num_round = 10 
bst = xgb.train(param, dtrain, 500, evals=evallist)
# Out:
# [0]	train-error:1.00000	test-error:1.00000
# [1]	train-error:0.00000	test-error:0.00000
# [2]	train-error:0.00000	test-error:0.00000
# [3]	train-error:0.00000	test-error:0.00000
# [4]	train-error:0.00000	test-error:0.00000
# [5]	train-error:0.00000	test-error:0.00000
# [6]	train-error:0.00000	test-error:0.00000
# [7]	train-error:0.00000	test-error:0.00000
# [8]	train-error:0.00000	test-error:0.00000
# [9]	train-error:0.00000	test-error:0.00000
# [10]	train-error:0.00000	test-error:0.00000
# [11]	train-error:0.00000	test-error:0.00000
# [12]	train-error:0.00000	test-error:0.00000
# [13]	train-error:0.00000	test-error:0.00000
# [14]	train-error:0.00000	test-error:0.00000
# [15]	train-error:0.00000	test-error:0.00000
# [16]	train-error:0.00000	test-error:0.00000
# [17]	train-error:0.00000	test-error:0.00000
# [18]	train-error:0.00000	test-error:0.00000
# [19]	train-error:0.00000	test-error:0.00000
# [20]	train-error:0.00000	test-error:0.00000
# ...
